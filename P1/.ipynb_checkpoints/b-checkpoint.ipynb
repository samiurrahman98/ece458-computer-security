# %%
import binascii

# %%
amt_0 = "0x05"
amt_1 = "0x04"
amt_2 = "0x03"

p = ...
q = 13479974306915323548855049186344013292925286365246579443817723220231
g = ...

sk_1 = 4001206756878977378588887638958103884884701595184090082238631140177
sk_2 = 5779569239846031148528787672249249942175134704083930000648821513800
sk_3 = 6969605852178656353201188977960624260949249162467496071645806103126

pk_1 = ...
pk_2 = ...
pk_3 = ...

# %%
# m1
l_1 = 2048 - len(bin(pk_1)[2:])
l_2 = 2048 - len(bin(pk_2)[2:])

# %%
l_1
# Out:
# 1

# %%
l_2
# Out:
# 1

# %%
m_1 = '0' + str(bin(pk_1)[2:]) + '0' + str(bin(pk_2)[2:]) + str(bin(int(amt_1, 16)))[2:].zfill(len(amt_1[2:] * 4))

# %%
len(m_1)
# Out:
# 4104

# %%
k = 7636180595255512892709086526638263042018821609914680860810683215268

# %%
k_inv = inverse_mod(k, q)

# %%
k_inv
# Out:
# 11729220182069551241724220000567628092726165596174026491062157107909

# %%
float(5 // 2)
# Out:
# 2.0
