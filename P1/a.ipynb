# %%
# binary literal starts from index 2 onwards of bin(n) output

# %%
p = ...

# %%
len(bin(p)[2:])
# Out:
# 2048

# %%
is_prime(p)
# Out:
# True

# %%
q = 13479974306915323548855049186344013292925286365246579443817723220231

# %%
len(bin(q)[2:])
# Out:
# 224

# %%
(p - 1) % q == 0
# Out:
# True

# %%
is_prime(q)
# Out:
# True

# %%
ecm.find_factor(p-1)
# Out:
# [2,
#  ...]

# %%
u = ...

# %%
is_prime(u)
# Out:
# False

# %%
ecm.find_factor((p-1)/q)
# Out:
# [2,
#  ...]

# %%
v = ...

# %%
is_prime(v)
# Out:
# True

# %%
g  = ...

# %%
is_prime(q)
# Out:
# True

# %%
pow(g, 2, p) == 1
# Out:
# False

# %%
pow(g, q, p) == 1
# Out:
# True

# %%
pow(g, v, p) == 1
# Out:
# False

# %%
(p-1) % q
# Out:
# 0

# %%
sk_1 = 4001206756878977378588887638958103884884701595184090082238631140177
sk_2 = 5779569239846031148528787672249249942175134704083930000648821513800
sk_3 = 6969605852178656353201188977960624260949249162467496071645806103126

# %%
pk_1 = pow(g, sk_1, p)
pk_2 = pow(g, sk_2, p)
pk_3 = pow(g, sk_3, p)

# %%
pk_3
# Out:
# ...

# %%
len(bin(44001206756878977378588887638958103884884701595184090082238631140177)[2:])
# Out:
# 225
